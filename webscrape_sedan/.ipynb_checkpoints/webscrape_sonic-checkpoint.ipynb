# %%
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
from requests_html import HTMLSession

import time

# %%
driver = webdriver.Chrome(executable_path='C:/Users/17178/Downloads/chromedriver_win32/chromedriver.exe')
driver.get('https://www.sonicautomotive.com/used-inventory/index.htm?normalBodyStyle=Sedan&start=0')
content = driver.page_source
soup = BeautifulSoup(content)

# %%
counter = []

for element in soup.findAll('span', {'class': 'd-none d-sm-inline'}):
    counter.append([int(s) for s in element.contents[0] if s.isdigit()])
    
def convert(counter):
      
    # Converting integer list to string list
    s = [str(i) for i in counter[0]]
      
    # Join list items using join()
    res = int("".join(s))
      
    return(res)

#number of used cars for sale
counter = convert(counter)
counter
# Out:
# 2193

# %%
for i in range(0,counter+1,35):
    driver.get(f'https://www.sonicautomotive.com/used-inventory/index.htm?normalBodyStyle=Sedan&start={i}')
    content = driver.page_source
    soup = BeautifulSoup(content)

    results_year_make = []
    results_miles  = []
    results_price = []

    for element in soup.findAll('div', {'class': 'ddc-wrapper'}):
        for year_make in element.findAll('span', {'class': 'ddc-font-size-small'}):
            results_year_make.append(year_make.contents[0])
        for price in element.findAll('span', {'class': 'price-value'}):
            results_price.append(price.contents[0])
        for miles in element.findAll('li', {'class': 'odometer'}):
            results_miles.append(miles.contents[0])

        df_temp = pd.DataFrame(
                    {'year_make': results_year_make,
                     'model_trim': 'missing',
                     'price': results_price,
                     'state': 'missing',
                     'miles': results_miles,
                     'source': 'sonic',
                     'type': 'sedan'
                    })


        df_temp['miles'] = df_temp['miles'].replace({'\,':''}, regex=True)
        try:
            df_temp['miles'] = df_temp['miles'].str.extract('([0-9]+)').astype(float)
        except:
            df_temp['miles'] = 'missing'

        df_temp['price'] = df_temp['price'].replace({'\$':''}, regex=True)
        df_temp['price'] = df_temp['price'].replace({',':''}, regex=True)

        if i == 0:
            df = df_temp
        else:
            df = pd.merge(df, df_temp, how='outer')
            del df_temp


df.to_csv(f'C:/Users/17178/Documents/DS Projects/Nitorum Case/Data/sonic_sedan.csv')
df
# Out:
#         year_make model_trim        price    state    miles source   type
# 0     2016 Acura     missing        19997  missing  41205.0  sonic  sedan
# 1     2016 Acura     missing        18499  missing  46222.0  sonic  sedan
# 2     2018 Acura     missing        21298  missing   6555.0  sonic  sedan
# 3     2018 Acura     missing        20999  missing  48805.0  sonic  sedan
# 4     2020 Acura     missing        26488  missing  12418.0  sonic  sedan
# ...           ...        ...          ...      ...      ...    ...    ...
# 2168  2018 Volvo     missing        32999  missing  23096.0  sonic  sedan
# 2169  2018 Volvo     missing        30778  missing  34944.0  sonic  sedan
# 2170  2018 Volvo     missing        30678  missing  20792.0  sonic  sedan
# 2171  2018 Volvo     missing        31498  missing  26883.0  sonic  sedan
# 2172  2018 Volvo     missing  Please Call  missing  41013.0  sonic  sedan
#
# [2173 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# year_make     0
# model_trim    0
# price         0
# state         0
# miles         2
# source        0
# type          0
# dtype: int64
